# %% [markdown]
# <a href="https://colab.research.google.com/github/cesarpaico1511/Modulo1_PythonFundamentalsDMC/blob/main/app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# !pip install pandas numpy matplotlib plotly
# Out:
# Python 3.12.13
# ...
